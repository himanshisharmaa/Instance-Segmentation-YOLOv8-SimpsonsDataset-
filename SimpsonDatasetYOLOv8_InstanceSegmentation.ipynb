# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.3/873.3 kB 22.9 MB/s eta 0:00:00
# ...

# %%
# !cp -r /content/drive/MyDrive/SimpsonDatasetYOLO/ /content/

# %%
# !ls /content/SimpsonDatasetYOLO/train/labels
# Out:
# bart_pic_0000.txt  homer_pic_0000.txt  lisa_pic_0000.txt    maggie_pic_0001.txt  marge_pic_0001.txt
# bart_pic_0001.txt  homer_pic_0001.txt  lisa_pic_0001.txt    maggie_pic_0002.txt  marge_pic_0002.txt
# bart_pic_0002.txt  homer_pic_0002.txt  lisa_pic_0002.txt    maggie_pic_0003.txt  marge_pic_0003.txt
# bart_pic_0003.txt  homer_pic_0003.txt  lisa_pic_0003.txt    maggie_pic_0004.txt  marge_pic_0004.txt
# bart_pic_0004.txt  homer_pic_0004.txt  lisa_pic_0004.txt    maggie_pic_0005.txt  marge_pic_0005.txt
# bart_pic_0005.txt  homer_pic_0005.txt  lisa_pic_0005.txt    maggie_pic_0006.txt  marge_pic_0006.txt
# bart_pic_0006.txt  homer_pic_0006.txt  lisa_pic_0006.txt    maggie_pic_0007.txt  marge_pic_0007.txt
# bart_pic_0007.txt  homer_pic_0007.txt  lisa_pic_0007.txt    maggie_pic_0008.txt  marge_pic_0008.txt
# bart_pic_0008.txt  homer_pic_0008.txt  lisa_pic_0008.txt    maggie_pic_0009.txt  marge_pic_0009.txt
# ...

# %%
# %cd SimpsonDatasetYOLO
# Out:
# /content/SimpsonDatasetYOLO

# %%
# !pwd
# Out:
# /content/SimpsonDatasetYOLO

# %%
# !yolo task=segment mode=train epochs=100 data=/content/SimpsonDatasetYOLO/data.yaml model=yolov8m-seg.pt imgsz=640 batch=8
# Out:
# ...
# 100% 52.4M/52.4M [00:00<00:00, 128MB/s]
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=predict source=/content/drive/MyDrive/test.mp4 model=/content/SimpsonDatasetYOLO/runs/segment/train/weights/best.pt
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27,225,279 parameters, 0 gradients, 110.0 GFLOPs
#
# video 1/1 (frame 1/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 74.0ms
# video 1/1 (frame 2/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.8ms
# video 1/1 (frame 3/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.7ms
# video 1/1 (frame 4/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.7ms
# video 1/1 (frame 5/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.8ms
# video 1/1 (frame 6/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.7ms
# video 1/1 (frame 7/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.7ms
# video 1/1 (frame 8/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 30.8ms
# video 1/1 (frame 9/716) /content/drive/MyDrive/test.mp4: 384x640 1 Homer, 19.1ms
# ...

# %%
# !mkdir /content/drive/MyDrive/NewSimpsonDatasetYOLO

# %%
# !cp -r /content/SimpsonDatasetYOLO/ /content/drive/MyDrive/NewSimpsonDatasetYOLO/
